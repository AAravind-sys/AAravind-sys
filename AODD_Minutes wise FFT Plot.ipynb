# %%
# Import Basic Packgaes 
import numpy as np
import pandas as pd
import datetime
import statsmodels as sm
import itertools
import glob
import os
from scipy.signal import argrelextrema
from scipy.signal import find_peaks, peak_widths

# Data Visualization
import matplotlib.pyplot as plt
import seaborn as sns # advanced vizs
from pandas.plotting import lag_plot

# Ignore Warnings
import warnings
warnings.filterwarnings("ignore")

# Set Color Palettes
palette1 = itertools.cycle(sns.color_palette(palette='Set1'))
palette2 = itertools.cycle(sns.color_palette(palette='Set2'))

# %%
os.chdir('D:\\TDMS\\4.P2_TDMS\\P2-CSV\\FFT 8Mar23 to 9Mar23')

# %%
os.getcwd()
# Out:
# 'D:\\TDMS\\4.P2_TDMS\\P2-CSV\\FFT 8Mar23 to 9Mar23'

# %%
# current directory csv files
csvs = [x for x in os.listdir('D:\\TDMS\\4.P2_TDMS\\P2-CSV\\FFT 8Mar23 to 9Mar23') if x.endswith('.csv')]
# stats.csv -> stats
fns = [os.path.splitext(os.path.basename(x))[0] for x in csvs]

dic_csv = {}
for i in range(len(fns)):
    dic_csv[fns[i]] = pd.read_csv(csvs[i])

# %%
dic_csv.keys()
# Out:
# dict_keys(['P2_lt_2023_02_27_raw', 'P2_lt_2023_02_28_raw', 'P2_lt_2023_03_08_raw', 'P2_lt_2023_03_09_raw'])

# %%
dic_csv['P2_lt_2023_02_27_raw'].info()

# %%
for key, df in dic_csv.items():
    df['Time'] =pd.to_datetime(df['Time'])

# %%
for key, df in dic_csv.items():
    df.set_index(['Time'], inplace=True)

# %%
a = len(dic_csv)  # number of rows
b = 1  # number of columns
c = 1  # initialize plot counter

fig1 = plt.figure(figsize=(30,90))

SMALL_SIZE = 16

for j,i in resample_dic_90ms.items():
    plt.subplot(a, b, c)
    #plt.vlines(x=i.index, ymin=0, ymax=i["Cycle-detect"])
    #plt.plot(i.index, i['P1-Water Discharge Pressure'])
    #plt.plot(i.index, i['P2-Air Supply Flowrate'])
    #plt.plot(i.index, i['P1-Air-Supply-pressure'])
    #plt.plot(i.index, i['P2-Water Suction Pressure'])
    #plt.plot(i.index, i['P2-Water Discharge Flowrate'])
    #plt.plot(i.index, i['CPM_diff'])
    plt.plot(i.index, i['P2-CPM'])
    plt.ylim(0,80)
    plt.title(j)
    c = c + 1

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=SMALL_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.show()

# %%
# Define FFT parameters
dt = 0.03
f1, f2 = 1000, 1000  # Hz
diff = 100

# %%
for key, df in dic_csv.items():
    # Define the time interval for slicing
    start_time = pd.to_datetime('00:00:00.000')
    end_time = pd.to_datetime('00:59:59.999')
    time_interval = pd.Timedelta(minutes=5)
    
    current_time = start_time
    while current_time <= end_time:
        next_time = current_time + time_interval

        # Slice the DataFrame based on the specified time range
        sliced_df = df.between_time(current_time.time(), next_time.time())

        # Perform FFT analysis only if there is data in the sliced DataFrame
        n = len(sliced_df)
        if n > 0:
            t = sliced_df.index
            s = sliced_df['P2-Air-Supply-pressure']

            # FFT
            s -= s.mean()
            fr = np.fft.fftfreq(n, dt)
            fou = np.fft.fft(s)

            # Plot and save the FFT plot
            plt.figure(figsize=(25, 10))
            plt.subplot(211)
            plt.plot(t, s)
            plt.title('Data with Noise')

            plt.subplot(212)
            plt.plot(np.fft.fftshift(fr), np.fft.fftshift(np.abs(fou)))
            plt.xticks(np.arange(min(np.fft.fftshift(fr)), max(np.fft.fftshift(fr)), 1))
            plt.ylim(0, 20000)
            plt.title('Spectrum of Noisy Data')

            # Save the plot with a meaningful filename
            filename = os.path.join('D:\\TDMS\\4.P2_TDMS\\P2-CSV\\FFT_Plots', f'{key}_{current_time.strftime("%H-%M-%S")}_{next_time.strftime("%H-%M-%S")}_FFT.png')
            plt.savefig(filename)
            plt.close()

        else:
            # Handle the case where the DataFrame is empty (e.g., print a message)
            print(f"No data in the time range {current_time} - {next_time}")

        current_time = next_time
# Out:
# No data in the time range 2023-10-25 00:00:00 - 2023-10-25 00:05:00
# No data in the time range 2023-10-25 00:05:00 - 2023-10-25 00:10:00
# No data in the time range 2023-10-25 00:10:00 - 2023-10-25 00:15:00
# No data in the time range 2023-10-25 00:15:00 - 2023-10-25 00:20:00
# No data in the time range 2023-10-25 00:20:00 - 2023-10-25 00:25:00
# No data in the time range 2023-10-25 00:25:00 - 2023-10-25 00:30:00
# No data in the time range 2023-10-25 00:30:00 - 2023-10-25 00:35:00
# No data in the time range 2023-10-25 00:35:00 - 2023-10-25 00:40:00
# No data in the time range 2023-10-25 00:40:00 - 2023-10-25 00:45:00
# No data in the time range 2023-10-25 00:45:00 - 2023-10-25 00:50:00
# No data in the time range 2023-10-25 00:50:00 - 2023-10-25 00:55:00
# No data in the time range 2023-10-25 00:55:00 - 2023-10-25 01:00:00
# No data in the time range 2023-10-25 00:00:00 - 2023-10-25 00:05:00
# No data in the time range 2023-10-25 00:05:00 - 2023-10-25 00:10:00
# No data in the time range 2023-10-25 00:10:00 - 2023-10-25 00:15:00
# No data in the time range 2023-10-25 00:15:00 - 2023-10-25 00:20:00
# No data in the time range 2023-10-25 00:20:00 - 2023-10-25 00:25:00
# No data in the time range 2023-10-25 00:25:00 - 2023-10-25 00:30:00
# No data in the time range 2023-10-25 00:30:00 - 2023-10-25 00:35:00
# No data in the time range 2023-10-25 00:35:00 - 2023-10-25 00:40:00
# No data in the time range 2023-10-25 00:40:00 - 2023-10-25 00:45:00
# No data in the time range 2023-10-25 00:45:00 - 2023-10-25 00:50:00
# No data in the time range 2023-10-25 00:50:00 - 2023-10-25 00:55:00
# No data in the time range 2023-10-25 00:55:00 - 2023-10-25 01:00:00
# No data in the time range 2023-10-25 00:00:00 - 2023-10-25 00:05:00
# No data in the time range 2023-10-25 00:05:00 - 2023-10-25 00:10:00
# No data in the time range 2023-10-25 00:10:00 - 2023-10-25 00:15:00
# No data in the time range 2023-10-25 00:15:00 - 2023-10-25 00:20:00
# No data in the time range 2023-10-25 00:20:00 - 2023-10-25 00:25:00
# No data in the time range 2023-10-25 00:25:00 - 2023-10-25 00:30:00
# No data in the time range 2023-10-25 00:30:00 - 2023-10-25 00:35:00
# No data in the time range 2023-10-25 00:35:00 - 2023-10-25 00:40:00
# No data in the time range 2023-10-25 00:40:00 - 2023-10-25 00:45:00
# No data in the time range 2023-10-25 00:45:00 - 2023-10-25 00:50:00
# No data in the time range 2023-10-25 00:50:00 - 2023-10-25 00:55:00
# No data in the time range 2023-10-25 00:55:00 - 2023-10-25 01:00:00
