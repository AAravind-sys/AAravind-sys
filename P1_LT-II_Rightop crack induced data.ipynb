# %%
# Import Basic Packgaes 
import numpy as np
import pandas as pd
from datetime import datetime
import statsmodels as sm
import itertools
import glob
import os
from scipy.signal import argrelextrema

# Data Visualization
import matplotlib.pyplot as plt
import seaborn as sns # advanced vizs
from pandas.plotting import lag_plot

# Ignore Warnings
import warnings
warnings.filterwarnings("ignore")

# Set Color Palettes
palette1 = itertools.cycle(sns.color_palette(palette='Set1'))
palette2 = itertools.cycle(sns.color_palette(palette='Set2'))
# %matplotlib qt

# %%
os.chdir("D:\\TDMS\\6.Pump_1_Right12'oclock crak left good\\CSV Files")

# %%
os.getcwd()
# Out:
# "D:\\TDMS\\6.Pump_1_Right12'oclock crak left good\\CSV Files"

# %%
# current directory csv files
csvs = [x for x in os.listdir("D:\\TDMS\\6.Pump_1_Right12'oclock crak left good\\CSV Files") if x.endswith('.csv')]
# stats.csv -> stats
fns = [os.path.splitext(os.path.basename(x))[0] for x in csvs]

dic_csv = {}
for i in range(len(fns)):
    dic_csv[fns[i]] = pd.read_csv(csvs[i])

# %%
dic_csv.keys()
# Out:
# dict_keys(['1_P1_R12clockcrackLgood_12Oct23'])

# %%
dic_csv['1_P1_R12clockcrackLgood_12Oct23'].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1319048 entries, 0 to 1319047
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count    Dtype
# ---  ------                       --------------    -----
#  0   Time                         1319048 non-null  object
#  1   Cycle-detect                 1319048 non-null  float64
#  2   P1-CPM                       1319048 non-null  float64
#  3   P1-Water Suction Pressure    1319048 non-null  float64
#  4   P1-Water Discharge Pressure  1319048 non-null  float64
#  5   P1-Channel-3                 1319048 non-null  float64
#  6   P1-Air-Supply-pressure       1319048 non-null  float64
#  7   P1-Water Suction Flowrate    1319048 non-null  float64
#  8   P1-Water Discharge Flowrate  1319048 non-null  float64
#  9   P1-Air Supply Flowrate       1319048 non-null  float64
# dtypes: float64(9), object(1)
# memory usage: 100.6+ MB

# %%
#Set time index
for key, df in zip(dic_csv.keys(),dic_csv.values()) :
    #df.reset_index(inplace=True)
    df['Time'] =pd.to_datetime(df['Time'])
    df.set_index(['Time'], inplace=True)

# %%
dic_csv['1_P1_R12clockcrackLgood_12Oct23']['P1-CPM-Round'] = dic_csv['1_P1_R12clockcrackLgood_12Oct23']['P1-CPM'] .round()

# %%
dic_csv['1_P1_R12clockcrackLgood_12Oct23']['P1-CPM_Rateofchange'] = dic_csv['1_P1_R12clockcrackLgood_12Oct23']['P1-CPM'].pct_change()

# %%
dic_csv['1_P1_R12clockcrackLgood_12Oct23']['P1-CPM_diff'] = abs(dic_csv['1_P1_R12clockcrackLgood_12Oct23']['P1-CPM'].diff())

# %%
dic_csv['1_P1_R12clockcrackLgood_12Oct23'].head()
# Out:
#                          Cycle-detect    P1-CPM  P1-Water Suction Pressure  \
# Time
# 2023-10-12 09:57:43.774           0.0  0.000000                  13.700301
# 2023-10-12 09:57:43.778           0.0  2.635381                  13.700301
# 2023-10-12 09:57:43.808           0.0  2.635381                  -1.848453
# 2023-10-12 09:57:43.838           0.0  2.635381                  -1.834446
# 2023-10-12 09:57:43.868           0.0  2.635381                  -1.834446
#
#                          P1-Water Discharge Pressure  P1-Channel-3  \
# Time
# 2023-10-12 09:57:43.774                    14.010488     14.010488
# 2023-10-12 09:57:43.778                    14.010488     14.010488
# 2023-10-12 09:57:43.808                   -27.596760    -28.507357
# 2023-10-12 09:57:43.838                   -27.176485    -28.297219
# 2023-10-12 09:57:43.868                   -26.896302    -28.157127
#
#                          P1-Air-Supply-pressure  P1-Water Suction Flowrate  \
# Time
# ...

# %%
a = len(dic_csv)  # number of rows
b = 1  # number of columns
c = 1  # initialize plot counter

fig1 = plt.figure(figsize=(30,150))

SMALL_SIZE = 16

for j,i in dic_csv.items():
    plt.subplot(a, b, c)
    #plt.vlines(x=df.index, ymin=0, ymax=df["Cycle-detect"], linestyles='dashdot',colors='blue')
    #plt.plot(i.index, i['P1-Air-Supply-pressure'])
    plt.plot(i.index, i['P1-CPM_diff'])
    plt.plot(i.index, i['P1-Air Supply Flowrate'])
    plt.title(j)
    c = c + 1

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=SMALL_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.show()

# %%
#Create new dictionary to store the sliced data frame
slice_dic = {}

# %%
# Data frame slice range
start_time = pd.to_datetime('08:19:00.000')
end_time = pd.to_datetime('08:20:59.000')
time_interval = pd.Timedelta(seconds=30)

# %%
# plot sliced df
current_time = start_time
while current_time <= end_time:
    next_time = current_time + time_interval
   
    for key, df in dic_csv.items():
        # Slice the DataFrame based on the specified time range
        sliced_df = df.between_time(current_time.time(), next_time.time())
        # Store the sliced DataFrame in the new dictionary
        slice_dic[key] = sliced_df

    a = len(slice_dic)  # number of rows
    b = 1  # number of columns
    c = 1  # initialize plot counter
    fig1 = plt.figure(figsize=(45,12))

    SMALL_SIZE = 25
    
    for key, df in slice_dic.items():
        # Create a subplot and save the plot
        plt.subplot(a, b, c)
        plt.vlines(x=df.index, ymin=0, ymax=df["P3-Cycle-Detect"], linestyles='dashdot',colors='blue')
        plt.plot(df.index, df['P3_CPM'],color='black')
        plt.plot(df.index, df['P3-Water Suction Pressure'])
        plt.plot(df.index, df['P3-Water Discharge Pressure'],color='magenta')
        plt.plot(df.index, df['P3-Air Suction Pressure'],color='red')
        #plt.plot(df.index, df['P1-Water Discharge Flowrate'],color='maroon')
        #plt.plot(df.index, df['P1-Air Supply Flowrate'],color='lime')             
        plt.ylim(0, 118)
        plt.title(key)
        plt.legend(df.columns, loc='lower center', bbox_to_anchor=(0.5, -0.14), ncol=8)
        c = c + 1

        plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
        plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
        plt.rc('axes', labelsize=SMALL_SIZE)    # fontsize of the x and y labels
        plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
        plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
        # Save the plot with a filename indicating the time interval

    filename = os.path.join("D:\\TDMS\\7.Pump_3_Lifetest-II\\CSV File - I", f'{key}_{current_time.strftime("%H-%M-%S")}_{next_time.strftime("%H-%M-%S")}.png')
    plt.savefig(filename)
    plt.close()
    
    current_time = next_time
